# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import os

# %%
# read the csv file
pd.read_csv(r'C:\Users\luist\OneDrive\data analysis\data analysis mexican gov salaries/salaries.csv')
# Out:
#         entidadfederativa                                     sujetoobligado  \
# 0                 Hidalgo                                           Jaltocán
# 1        Ciudad de México                                Secretaría de Salud
# 2        Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3              Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4          Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
# ...                   ...                                                ...
# 1978150  Ciudad de México                                   Policía Auxiliar
# 1978151          Guerrero             Secretaría de Educación Guerrero (SEG)
# 1978152           Chiapas                      Secretaría/Instituto de Salud
# 1978153           Chiapas     Secretaría de Seguridad y Protección Ciudadana
# 1978154        Federación              Pemex Transformación Industrial (TRI)
#
#                                    nombre  \
# ...

# %%
# create a dataframe with the info of this dataset
salariesmex = pd.read_csv(r'C:\Users\luist\OneDrive\data analysis\data analysis mexican gov salaries/salaries.csv')

# %%
salariesmex
# Out:
#         entidadfederativa                                     sujetoobligado  \
# 0                 Hidalgo                                           Jaltocán
# 1        Ciudad de México                                Secretaría de Salud
# 2        Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3              Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4          Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
# ...                   ...                                                ...
# 1978150  Ciudad de México                                   Policía Auxiliar
# 1978151          Guerrero             Secretaría de Educación Guerrero (SEG)
# 1978152           Chiapas                      Secretaría/Instituto de Salud
# 1978153           Chiapas     Secretaría de Seguridad y Protección Ciudadana
# 1978154        Federación              Pemex Transformación Industrial (TRI)
#
#                                    nombre  \
# ...

# %%
# check the number of rows and columns of this dataset / dataframe
salariesmex.shape
# Out:
# (1978155, 11)

# %%
type(salariesmex)
# Out:
# pandas.core.frame.DataFrame

# %%
# check for duplicated values
salariesmex.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1978150    False
# 1978151    False
# 1978152    False
# 1978153    False
# 1978154    False
# Length: 1978155, dtype: bool

# %%
# with this code we can check the sum of duplicated values
# there are not duplicated values so the value is 0
salariesmex.duplicated().sum()
# Out:
# 0

# %%
# check for the null values
salariesmex.isnull()
# Out:
#          entidadfederativa  sujetoobligado  nombre  denominacion  montoneto  \
# 0                    False           False   False         False      False
# 1                    False           False   False         False      False
# 2                    False           False   False         False      False
# 3                    False           False   False         False      False
# 4                    False           False   False         False      False
# ...                    ...             ...     ...           ...        ...
# 1978150              False           False   False         False      False
# 1978151              False           False   False         False       True
# 1978152              False           False   False         False      False
# 1978153              False           False   False         False      False
# 1978154              False           False   False         False      False
#
# ...

# %%
# check the sum of null values
salariesmex.isnull().sum()
# Out:
# entidadfederativa           0
# sujetoobligado              0
# nombre                  31618
# denominacion            52799
# montoneto               89176
# cargo                   52799
# area                    33218
# montobruto              39422
# idInformacion               0
# periodoreportainicio        0
# periodoreportafin           0
# dtype: int64

# %%
# see if there are duplicated values
salariesmex.duplicated().sum()
# Out:
# 0

# %%
# drop the null values
salariesmex_clean = salariesmex.dropna()

# %%
# updated the dataframe without null values
salariesmex_clean.isnull().sum()
# Out:
# entidadfederativa       0
# sujetoobligado          0
# nombre                  0
# denominacion            0
# montoneto               0
# cargo                   0
# area                    0
# montobruto              0
# idInformacion           0
# periodoreportainicio    0
# periodoreportafin       0
# dtype: int64

# %%
salariesmex_clean
# Out:
#         entidadfederativa                                     sujetoobligado  \
# 0                 Hidalgo                                           Jaltocán
# 1        Ciudad de México                                Secretaría de Salud
# 2        Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3              Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4          Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
# ...                   ...                                                ...
# 1978149           Chiapas                            Secretaría de Educación
# 1978150  Ciudad de México                                   Policía Auxiliar
# 1978152           Chiapas                      Secretaría/Instituto de Salud
# 1978153           Chiapas     Secretaría de Seguridad y Protección Ciudadana
# 1978154        Federación              Pemex Transformación Industrial (TRI)
#
#                                  nombre  \
# ...

# %%
# datatypes
salariesmex_clean.dtypes
# Out:
# entidadfederativa        object
# sujetoobligado           object
# nombre                   object
# denominacion             object
# montoneto               float64
# cargo                    object
# area                     object
# montobruto              float64
# idInformacion             int64
# periodoreportainicio     object
# periodoreportafin        object
# dtype: object

# %%
salariesmex_clean['periodoreportainicio'][77]
# Out:
# '01/10/2017'

# %%
# ignore the special messages
import warnings
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# change data format
salariesmex_clean['periodoreportainicio'] = pd.to_datetime(salariesmex_clean['periodoreportainicio'], errors='coerce')

# %%
salariesmex_clean['periodoreportainicio'][77]
# Out:
# Timestamp('2017-01-10 00:00:00')

# %%
# change data format
salariesmex_clean['periodoreportafin'] = pd.to_datetime(salariesmex_clean['periodoreportafin'], errors='coerce')

# %%
salariesmex_clean['periodoreportainicio'].dtype
# Out:
# dtype('<M8[ns]')

# %%
salariesmex_clean['periodoreportafin'].dtype
# Out:
# dtype('<M8[ns]')

# %%
# just keep the format YYYY/MM/DD
# drop the hours, minutes, seconds information
pd.to_datetime(salariesmex_clean['periodoreportafin'], unit='s')
# Out:
# 0         2018-06-30
# 1         2018-03-31
# 2         2020-03-31
# 3         2018-12-31
# 4         2019-12-31
#              ...
# 1978149   2018-12-31
# 1978150   2019-06-30
# 1978152   2020-06-30
# 1978153   2018-06-30
# 1978154   2019-06-30
# Name: periodoreportafin, Length: 1850529, dtype: datetime64[ns]

# %%
# just keep the format YYYY/MM/DD
# drop the hours, minutes, seconds information
pd.to_datetime(salariesmex_clean['periodoreportainicio'], unit='s')
# Out:
# 0         2018-01-01
# 1         2018-01-01
# 2         2020-01-01
# 3         2018-01-07
# 4         2019-01-07
#              ...
# 1978149   2018-01-07
# 1978150   2019-01-04
# 1978152   2020-01-01
# 1978153   2018-01-04
# 1978154   2019-01-01
# Name: periodoreportainicio, Length: 1850529, dtype: datetime64[ns]

# %%
salariesmex_clean
# Out:
#         entidadfederativa                                     sujetoobligado  \
# 0                 Hidalgo                                           Jaltocán
# 1        Ciudad de México                                Secretaría de Salud
# 2        Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3              Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4          Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
# ...                   ...                                                ...
# 1978149           Chiapas                            Secretaría de Educación
# 1978150  Ciudad de México                                   Policía Auxiliar
# 1978152           Chiapas                      Secretaría/Instituto de Salud
# 1978153           Chiapas     Secretaría de Seguridad y Protección Ciudadana
# 1978154        Federación              Pemex Transformación Industrial (TRI)
#
#                                  nombre  \
# ...

# %%
salariesmex_clean.shape
# Out:
# (1850529, 11)

# %%
salariesmex_clean.dtypes
# Out:
# entidadfederativa               object
# sujetoobligado                  object
# nombre                          object
# denominacion                    object
# montoneto                      float64
# cargo                           object
# area                            object
# montobruto                     float64
# idInformacion                    int64
# periodoreportainicio    datetime64[ns]
# periodoreportafin       datetime64[ns]
# dtype: object

# %%
salariesmex_clean.columns
# Out:
# Index(['entidadfederativa', 'sujetoobligado', 'nombre', 'denominacion',
#        'montoneto', 'cargo', 'area', 'montobruto', 'idInformacion',
#        'periodoreportainicio', 'periodoreportafin'],
#       dtype='object')

# %%
# rename columns
salariesmex_clean.rename(columns={'entidadfederativa':'Entidad_Federativa',
                   'sujetoobligado':'Sujeto_Obligado','nombre':'Nombre', 
                   'denominacion': 'Denominacion', 'montoneto':'Monto_Neto',
                   'cargo':'Cargo', 'area': 'Area', 'montobruto': 'Monto_Bruto', 
                   'idInformacion': 'ID', 'periodoreportainicio': 'Periodo_Reporta_Inicio', 
                   'periodoreportafin': 'Periodo_Reporta_Fin'},inplace=True)

# %%
salariesmex_clean.head(7)
# Out:
#   Entidad_Federativa                                    Sujeto_Obligado  \
# 0            Hidalgo                                           Jaltocán
# 1   Ciudad de México                                Secretaría de Salud
# 2   Ciudad de México                  Secretaría de Seguridad Ciudadana
# 3         Federación  Autoridad Educativa Federal en la Ciudad de Mé...
# 4     Aguascalientes                       MUNICIPIO DE RINCÓN DE ROMOS
# 5     Aguascalientes             UNIVERSIDAD AUTÓNOMA DE AGUASCALIENTES
# 6           Campeche                          Ayuntamiento de Escárcega
#
#                            Nombre                       Denominacion  \
# 0      Adolfo Hernandez Hernandez                          Fontanero
# 1   ARELY SAMANTA CLEOFAS VELASCO         AUXILIAR DE ENFERMERIA "A"
# 2  MELODY OLIMPIC GONZALEZ MONTES                    POLICIA PRIMERO
# 3            ANGEL ALLENDE PULIDO  APOYO Y ASISTENCIA A LA EDUCACION
# ...

# %%
salariesmex_clean.columns
# Out:
# Index(['Entidad_Federativa', 'Sujeto_Obligado', 'Nombre', 'Denominacion',
#        'Monto_Neto', 'Cargo', 'Area', 'Monto_Bruto', 'ID',
#        'Periodo_Reporta_Inicio', 'Periodo_Reporta_Fin'],
#       dtype='object')

# %%
salariesmex_clean.shape
# Out:
# (1850529, 11)

# %%
# change the order of the columns

salariesmex_clean = salariesmex_clean.reindex(columns=['ID','Nombre', 'Cargo', 'Area', 'Entidad_Federativa', 'Monto_Neto', 'Monto_Bruto',
                               'Sujeto_Obligado', 'Denominacion', 'Periodo_Reporta_Inicio', 'Periodo_Reporta_Fin'])

# %%
salariesmex_clean
# Out:
#                ID                          Nombre  \
# 0        16311845      Adolfo Hernandez Hernandez
# 1        16480190   ARELY SAMANTA CLEOFAS VELASCO
# 2        17599078  MELODY OLIMPIC GONZALEZ MONTES
# 3         6514612            ANGEL ALLENDE PULIDO
# 4        11927166          Yolanda Reyes Gonzalez
# ...           ...                             ...
# 1978149  12446137               JUANA GOMEZ LOPEZ
# 1978150  18698843     Nancy Fanny Rivera Martinez
# 1978152  11695594          SEBASTIAN GOMEZ SANTIZ
# 1978153  12038916             Santana Reyes Gómez
# 1978154   1511822    JOSE ALFREDO GONZALEZ MORENO
#
#                                                      Cargo  \
# 0                                                Fontanero
# 1                               AUXILIAR DE ENFERMERIA "A"
# 2                                          POLICIA PRIMERO
# 3                        APOYO Y ASISTENCIA A LA EDUCACION
# 4                                                 DIRECTOR
# ...

# %%
salariesmex_clean.head(1000)
# Out:
#             ID                           Nombre  \
# 0     16311845       Adolfo Hernandez Hernandez
# 1     16480190    ARELY SAMANTA CLEOFAS VELASCO
# 2     17599078   MELODY OLIMPIC GONZALEZ MONTES
# 3      6514612             ANGEL ALLENDE PULIDO
# 4     11927166           Yolanda Reyes Gonzalez
# ...        ...                              ...
# 1070  16243407          Oviel Leines De La Cruz
# 1071  16842134           CELERINA LEYVA RAMIREZ
# 1072   7121399     DAVID GONZALO VALENCIA TAPIA
# 1073  42544440  OR MA. ANGELINA MUNGUIA VILLASE
# 1074   7356469  ROSALBA DOMINGUEZ S INFORMACION
#
#                                                   Cargo  \
# 0                                             Fontanero
# 1                            AUXILIAR DE ENFERMERIA "A"
# 2                                       POLICIA PRIMERO
# 3                     APOYO Y ASISTENCIA A LA EDUCACION
# 4                                              DIRECTOR
# ...

# %%
# next changes. Change capital upper letters to just first capital letter and rest 
cols = ['Nombre', 'Cargo', 'Area', 'Sujeto_Obligado', 'Denominacion']
salariesmex_clean[cols] = salariesmex_clean[cols].apply(lambda x: x.str.title(), axis=1)

# %%
salariesmex_clean.columns
# Out:
# Index(['ID', 'Nombre', 'Cargo', 'Area', 'Entidad_Federativa', 'Monto_Neto',
#        'Monto_Bruto', 'Sujeto_Obligado', 'Denominacion',
#        'Periodo_Reporta_Inicio', 'Periodo_Reporta_Fin'],
#       dtype='object')

# %%
salariesmex_clean
# Out:
#                ID                          Nombre  \
# 0        16311845      Adolfo Hernandez Hernandez
# 1        16480190   Arely Samanta Cleofas Velasco
# 2        17599078  Melody Olimpic Gonzalez Montes
# 3         6514612            Angel Allende Pulido
# 4        11927166          Yolanda Reyes Gonzalez
# ...           ...                             ...
# 1978149  12446137               Juana Gomez Lopez
# 1978150  18698843     Nancy Fanny Rivera Martinez
# 1978152  11695594          Sebastian Gomez Santiz
# 1978153  12038916             Santana Reyes Gómez
# 1978154   1511822    Jose Alfredo Gonzalez Moreno
#
#                                                      Cargo  \
# 0                                                Fontanero
# 1                               Auxiliar De Enfermeria "A"
# 2                                          Policia Primero
# 3                        Apoyo Y Asistencia A La Educacion
# 4                                                 Director
# ...

# %%
salariesmex_clean.to_csv('C:/Users/luist/Desktop/mexican salaries gov.csv', index=False)
